# %% [markdown]
# # Optimisation: Compilation
#
# Compilation is the act of a program, known as a compiler, examining source code and creating a new piece of executable code which may be executed later. Compilation offers a few useful advantages. A compiler can check the syntax of all the code of a program before it is run, which can aid finding problems in the code. Of more immediate use to us, however, is the fact that compilers can interpret our code and write a more efficient piece of code in a lower level language which is guaranteed to produce the same result. This is the property of compilation that we can use to speed up code written in Python.
#
# Some languages are, by default, compiled languages, such as Fortran and C. Code written in these languages are usually compiled before they are run. In these cases, a separate exceutable file is normally created and this is what is run, without reference to the source code at all.
#
# Python code can be compiled this way, but there are other, more convenient ways of using the idea of compilation to speed up Python code.
#
# ## Numba
#
# [Numba](http://numba.pydata.org/) is an example of a Python tool which harnesses the power of compilation to speed up existing Python code with minimal changes to code required. Many of the features in Numba are accessed by adding various decorators to functions. Let's look at a simple example now.
#
# The following example is taken from a series of short examples from the [Numba website](https://numba.pydata.org/). The first code calcualtes the value of $\pi$ using the same method we used in the Parallelism notebook. In the second code cell we import the ```jit``` decorator from the ```numba``` package and add the decorator ```@jit(nopython=True)``` to the function. This causes Numba to compile the function just before it's run and for Python to run the compiled function. Here, ```jit``` stands for "just in time" as the compilation is happening just before the function is run. The ```nonpython = true``` forces Numba to attempt to compile the function using faster, non-Python, code.
#
# If you're running this Jupyter Notebook on your computer, as opposed to Colab, you may need to install the Numba package before you can run the code.

# %%
import random
import cProfile

def monte_carlo_pi(nsamples):
    acc = 0
    for i in range(nsamples):
        x = random.random()
        y = random.random()
        if (x ** 2 + y ** 2) < 1.0:
            acc += 1
    return 4.0 * acc / nsamples

cProfile.run('print(monte_carlo_pi(10000000))')
# Out:
# 3.1419332
#          20000039 function calls in 5.591 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    4.335    4.335    5.590    5.590 <ipython-input-1-c431711fad5c>:4(monte_carlo_pi)
#         1    0.000    0.000    5.590    5.590 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 socket.py:432(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         1    0.000    0.000    5.591    5.591 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#  20000000    1.256    0.000    1.256    0.000 {method 'random' of '_random.Random' objects}

# %%
# Import the jit decorator from the numba package
from numba import jit
import random
import cProfile

# Apply the jit decorator to our function
@jit(nopython=True)
def monte_carlo_pi(nsamples):
    acc = 0
    for i in range(nsamples):
        x = random.random()
        y = random.random()
        if (x ** 2 + y ** 2) < 1.0:
            acc += 1
    return 4.0 * acc / nsamples

cProfile.run('monte_carlo_pi(10000000)')
# Out:
#          477261 function calls (453882 primitive calls) in 0.675 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1088    0.001    0.000    0.002    0.000 <__array_function__ internals>:2(can_cast)
#       184    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:103(release)
#       139    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#       139    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:147(__enter__)
#       139    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:151(__exit__)
#       184    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       138    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#    209/28    0.000    0.000    0.149    0.005 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#       927    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:232(_requires_builtin_wrapper)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:269(_module_repr)
#       134    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#       134    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#       134    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:318(__exit__)
#       536    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#       113    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#       138    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#       246    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:403(cached)
#      1172    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#       140    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:433(spec_from_loader)
#       134    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#       134    0.000    0.000    0.025    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#       138    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:581(_module_repr_from_spec)
#    134/28    0.001    0.000    0.148    0.005 <frozen importlib._bootstrap>:651(_load_unlocked)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:698(module_repr)
#       138    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:707(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:728(create_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:736(exec_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:753(is_package)
#       184    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:78(acquire)
#       137    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:780(find_spec)
#       842    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:843(__enter__)
#       842    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:847(__exit__)
#       430    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:861(_find_spec_legacy)
#       138    0.002    0.000    0.013    0.000 <frozen importlib._bootstrap>:870(_find_spec)
#    139/28    0.001    0.000    0.151    0.005 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#    139/28    0.001    0.000    0.152    0.005 <frozen importlib._bootstrap>:966(_find_and_load)
# 1875/1130    0.002    0.000    0.152    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1067(_path_hooks)
#       160    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#       137    0.000    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1117(_get_spec)
#       137    0.000    0.000    0.010    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1196(__init__)
#        80    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1202(<genexpr>)
#       133    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1228(_get_spec)
#       152    0.002    0.000    0.009    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1281(_fill_cache)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1322(path_hook_for_FileFinder)
#       226    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:263(cache_from_source)
#       133    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:361(_get_cached)
#       113    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:393(_check_name_wrapper)
#       152    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:41(_relax_case)
#       113    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:430(_validate_bytecode_header)
#       113    0.000    0.000    0.015    0.000 <frozen importlib._bootstrap_external>:485(_compile_bytecode)
#       226    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:52(_r_long)
#       133    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:524(spec_from_file_location)
#       803    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#       803    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#       226    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:63(_path_split)
#       113    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:669(create_module)
#    113/28    0.000    0.000    0.147    0.005 <frozen importlib._bootstrap_external>:672(exec_module)
#       113    0.001    0.000    0.047    0.000 <frozen importlib._bootstrap_external>:743(get_code)
#       438    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#       113    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:800(__init__)
#       113    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:825(get_filename)
#       113    0.003    0.000    0.028    0.000 <frozen importlib._bootstrap_external>:830(get_data)
#       113    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:840(path_stats)
#       173    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:85(_path_is_mode_type)
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:908(__init__)
#        20    0.000    0.000    0.021    0.001 <frozen importlib._bootstrap_external>:919(create_module)
#     20/17    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:927(exec_module)
#       163    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:94(_path_isfile)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:99(_path_isdir)
#         1    0.138    0.138    0.138    0.138 <ipython-input-2-37747d820d0d>:7(monte_carlo_pi)
#         1    0.000    0.000    0.676    0.676 <string>:1(<module>)
#        98    0.000    0.000    0.000    0.000 <string>:12(__new__)
#         1    0.000    0.000    0.000    0.000 <string>:5(ArgSpec)
#         1    0.000    0.000    0.000    0.000 <string>:5(Indexing)
#         1    0.000    0.000    0.000    0.000 <string>:5(MachAr)
#         1    0.000    0.000    0.000    0.000 <string>:5(_ArrayHelper)
#         1    0.000    0.000    0.000    0.000 <string>:5(_ArrayIndexingHelper)
#         1    0.000    0.000    0.000    0.000 <string>:5(finfo)
#         1    0.000    0.000    0.000    0.000 <string>:5(iinfo)
#         1    0.000    0.000    0.000    0.000 __config__.py:3(<module>)
#         1    0.000    0.000    0.002    0.002 __init__.py:1(<module>)
#         1    0.000    0.000    0.023    0.023 __init__.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:109(_FFTModule)
#         1    0.000    0.000    0.000    0.000 __init__.py:11(<module>)
#         1    0.000    0.000    0.002    0.002 __init__.py:112(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:1286(debug)
#         1    0.000    0.000    0.004    0.004 __init__.py:151(<module>)
#         2    0.000    0.000    0.000    0.000 __init__.py:1530(getEffectiveLevel)
#         2    0.000    0.000    0.000    0.000 __init__.py:1544(isEnabledFor)
#         1    0.000    0.000    0.030    0.030 __init__.py:189(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:215(<listcomp>)
#         1    0.000    0.000    0.015    0.015 __init__.py:219(<module>)
#         4    0.000    0.000    0.000    0.000 __init__.py:23(find_module)
#         1    0.000    0.000    0.000    0.000 __init__.py:244(<listcomp>)
#       382    0.000    0.000    0.000    0.000 __init__.py:2845(get_entry_map)
#         7    0.000    0.000    0.004    0.001 __init__.py:357(namedtuple)
#         1    0.000    0.000    0.000    0.000 __init__.py:4(<module>)
#        61    0.000    0.000    0.000    0.000 __init__.py:420(<genexpr>)
#        61    0.000    0.000    0.000    0.000 __init__.py:422(<genexpr>)
#         3    0.000    0.000    0.000    0.000 __init__.py:47(create_string_buffer)
#        22    0.000    0.000    0.000    0.000 __init__.py:484(cast)
#         2    0.000    0.000    0.000    0.000 __init__.py:488(string_at)
#        10    0.000    0.000    0.000    0.000 __init__.py:517(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:537(__missing__)
#         1    0.001    0.001    0.019    0.019 __init__.py:58(<module>)
#        10    0.000    0.000    0.000    0.000 __init__.py:586(update)
#         1    0.000    0.000    0.000    0.000 __init__.py:630(iter_entry_points)
#         1    0.000    0.000    0.001    0.001 __init__.py:638(<genexpr>)
#       383    0.000    0.000    0.000    0.000 __init__.py:652(__iter__)
#         1    0.000    0.000    0.008    0.008 __init__.py:72(<module>)
#         5    0.000    0.000    0.000    0.000 __init__.py:73(CFUNCTYPE)
#         5    0.000    0.000    0.000    0.000 __init__.py:99(CFunctionType)
#       138    0.000    0.000    0.000    0.000 _altair.py:25(find_module)
#         2    0.000    0.000    0.001    0.001 _backend.py:1(<module>)
#        26    0.000    0.000    0.002    0.000 _backend.py:102(generate_multimethod)
#        26    0.000    0.000    0.002    0.000 _backend.py:216(get_defaults)
#         1    0.000    0.000    0.000    0.000 _backend.py:234(set_global_backend)
#         1    0.000    0.000    0.000    0.000 _backend.py:30(_backend_from_arg)
#         1    0.000    0.000    0.000    0.000 _backend.py:309(Dispatchable)
#         1    0.000    0.000    0.000    0.000 _backend.py:45(set_global_backend)
#         1    0.000    0.000    0.000    0.000 _backend.py:5(_ScipyBackend)
#         1    0.000    0.000    0.004    0.004 _basic.py:1(<module>)
#        26    0.000    0.000    0.002    0.000 _basic.py:16(_dispatch)
#       138    0.000    0.000    0.000    0.000 _bokeh.py:36(find_module)
#         1    0.000    0.000    0.001    0.001 _ccallback.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _ccallback.py:26(LowLevelCallable)
#         1    0.000    0.000    0.000    0.000 _ccallback.py:9(CData)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:252(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:672(keys)
#         4    0.000    0.000    0.000    0.000 _collections_abc.py:676(items)
#         6    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:701(__len__)
#        34    0.000    0.000    0.000    0.000 _collections_abc.py:719(__iter__)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#       118    0.000    0.000    0.000    0.000 _collections_abc.py:742(__iter__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:879(__iter__)
#       138    0.000    0.000    0.000    0.000 _cv2.py:70(find_module)
#         1    0.000    0.000    0.000    0.000 _decomp_ldl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _decomp_polar.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _decomp_qz.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _distributor_init.py:10(<module>)
#         1    0.000    0.000    0.000    0.000 _expm_frechet.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 _helper.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _index.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 _index.py:30(IndexMixin)
#        90    0.000    0.000    0.000    0.000 _internal.py:784(_ufunc_doc_signature_formatter)
#       123    0.000    0.000    0.000    0.000 _internal.py:795(<genexpr>)
#         9    0.000    0.000    0.000    0.000 _internal.py:805(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _laplacian.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _matfuncs_sqrtm.py:22(SqrtmError)
#         1    0.000    0.000    0.000    0.000 _matfuncs_sqrtm.py:6(<module>)
#         1    0.000    0.000    0.000    0.000 _matrix_io.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 _numpy_compat.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 _procrustes.py:4(<module>)
#         1    0.000    0.000    0.001    0.001 _realtransforms.py:1(<module>)
#         1    0.000    0.000    0.015    0.015 _sketches.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _solvers.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _testutils.py:16(FPUModeChangeWarning)
#         1    0.000    0.000    0.000    0.000 _testutils.py:21(PytestTester)
#         7    0.000    0.000    0.000    0.000 _testutils.py:26(__init__)
#         1    0.000    0.000    0.000    0.000 _testutils.py:4(<module>)
#         1    0.000    0.000    0.001    0.001 _util.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 _util.py:139(DeprecatedImport)
#         2    0.000    0.000    0.000    0.000 _util.py:157(__init__)
#         1    0.000    0.000    0.000    0.000 _util.py:350(MapWrapper)
#        36    0.000    0.000    0.000    0.000 _utils.py:11(__init__)
#      2575    0.001    0.000    0.001    0.000 _utils.py:15(is_used)
#      1405    0.001    0.000    0.004    0.000 _utils.py:18(register)
#      1371    0.002    0.000    0.003    0.000 _utils.py:26(deduplicate)
# 3555/1425    0.002    0.000    0.017    0.000 _utils.py:46(__str__)
# 2640/2630    0.002    0.000    0.004    0.000 _utils.py:56(get_reference)
#        15    0.000    0.000    0.000    0.000 _utils.py:66(set_metadata)
#      1089    0.000    0.000    0.000    0.000 _utils.py:72(_stringify_metadata)
#        15    0.000    0.000    0.000    0.000 _utils.py:77(<listcomp>)
#         1    0.000    0.000    0.001    0.001 _validation.py:1(<module>)
#         8    0.000    0.000    0.000    0.000 _version.py:114(_compare)
#         1    0.000    0.000    0.000    0.000 _version.py:136(__lt__)
#         2    0.000    0.000    0.000    0.000 _version.py:148(__gt__)
#         5    0.000    0.000    0.000    0.000 _version.py:151(__ge__)
#         1    0.000    0.000    0.000    0.000 _version.py:17(NumpyVersion)
#        16    0.000    0.000    0.001    0.000 _version.py:55(__init__)
#        16    0.000    0.000    0.000    0.000 _version.py:62(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _version.py:7(<module>)
#         2    0.000    0.000    0.000    0.000 _version.py:70(<listcomp>)
#         8    0.000    0.000    0.000    0.000 _version.py:78(_compare_version)
#       870    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#       870    0.001    0.000    0.001    0.000 _weakrefset.py:20(__enter__)
#       870    0.001    0.000    0.001    0.000 _weakrefset.py:26(__exit__)
#        12    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#       870    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#       870    0.001    0.000    0.004    0.000 _weakrefset.py:58(__iter__)
#     14092    0.005    0.000    0.005    0.000 _weakrefset.py:70(__contains__)
#       908    0.001    0.000    0.001    0.000 _weakrefset.py:81(add)
#         4    0.000    0.000    0.000    0.000 abc.py:132(__new__)
#         4    0.000    0.000    0.000    0.000 abc.py:135(<setcomp>)
#      6326    0.006    0.000    0.016    0.000 abc.py:180(__instancecheck__)
# 2050/1308    0.004    0.000    0.011    0.000 abc.py:196(__subclasscheck__)
#       122    0.000    0.000    0.000    0.000 abc.py:243(get_cache_token)
#       441    0.000    0.000    0.000    0.000 abstract.py:118(__repr__)
# 2526/2288    0.002    0.000    0.003    0.000 abstract.py:121(__hash__)
# 5119/4954    0.002    0.000    0.003    0.000 abstract.py:124(__eq__)
#       113    0.000    0.000    0.000    0.000 abstract.py:127(__ne__)
#       260    0.000    0.000    0.000    0.000 abstract.py:151(can_convert_from)
#       266    0.000    0.000    0.000    0.000 abstract.py:158(is_precise)
#         2    0.000    0.000    0.000    0.000 abstract.py:177(__call__)
#       680    0.000    0.000    0.000    0.000 abstract.py:22(_autoincr)
#         2    0.000    0.000    0.000    0.000 abstract.py:247(unify)
#       193    0.000    0.000    0.000    0.000 abstract.py:30(_on_type_disposal)
#         1    0.000    0.000    0.000    0.000 abstract.py:411(__init__)
#        16    0.000    0.000    0.000    0.000 abstract.py:421(_literal_init)
#        30    0.000    0.000    0.000    0.000 abstract.py:432(literal_value)
#       410    0.000    0.000    0.000    0.000 abstract.py:436(literal_type)
#       851    0.001    0.000    0.004    0.000 abstract.py:51(_intern)
#   851/849    0.001    0.000    0.010    0.000 abstract.py:63(__call__)
#       851    0.000    0.000    0.000    0.000 abstract.py:96(__init__)
#      4586    0.001    0.000    0.001    0.000 abstract.py:99(key)
#        12    0.002    0.000    0.004    0.000 analysis.py:118(compute_dead_maps)
#       414    0.000    0.000    0.000    0.000 analysis.py:138(<genexpr>)
#       310    0.000    0.000    0.000    0.000 analysis.py:141(<genexpr>)
#       204    0.000    0.000    0.000    0.000 analysis.py:182(<genexpr>)
#        12    0.001    0.000    0.001    0.000 analysis.py:190(compute_live_variables)
#        36    0.000    0.000    0.000    0.000 analysis.py:200(fix_point_progress)
#        12    0.002    0.000    0.014    0.001 analysis.py:23(compute_use_defs)
#        30    0.001    0.000    0.018    0.001 analysis.py:235(compute_cfg_from_blocks)
#         4    0.000    0.000    0.003    0.001 analysis.py:287(dead_branch_prune)
#         4    0.000    0.000    0.000    0.000 analysis.py:299(find_branches)
#         4    0.000    0.000    0.000    0.000 analysis.py:349(Unknown)
#         2    0.000    0.000    0.000    0.000 analysis.py:352(resolve_input_arg_const)
#       648    0.000    0.000    0.000    0.000 analysis.py:40(<genexpr>)
#         4    0.000    0.000    0.000    0.000 analysis.py:432(<listcomp>)
#         2    0.000    0.000    0.000    0.000 analysis.py:459(rewrite_semantic_constants)
#        41    0.000    0.000    0.000    0.000 analysis.py:486(rewrite_array_ndim)
#        41    0.000    0.000    0.000    0.000 analysis.py:496(rewrite_tuple_len)
#         2    0.000    0.000    0.000    0.000 analysis.py:525(find_literally_calls)
#        12    0.000    0.000    0.005    0.000 analysis.py:60(compute_live_map)
#       132    0.000    0.000    0.001    0.000 analysis.py:66(fix_point_progress)
#      2136    0.000    0.000    0.001    0.000 analysis.py:69(<genexpr>)
#        24    0.000    0.000    0.005    0.000 analysis.py:71(fix_point)
#        36    0.001    0.000    0.002    0.000 analysis.py:81(def_reach)
#        72    0.001    0.000    0.002    0.000 analysis.py:91(liveness)
#        75    0.000    0.000    0.001    0.000 api.py:194(typeof)
#         1    0.000    0.000    0.000    0.000 api.py:293(cast)
#         1    0.000    0.000    0.047    0.047 api.py:41(__init__)
#         2    0.000    0.000    0.000    0.000 api.py:433(_get_cached_btype)
#        72    0.000    0.000    0.000    0.000 api.py:952(_builtin_function_type)
#         2    0.000    0.000    0.000    0.000 array_exprs.py:27(__init__)
#        32    0.000    0.000    0.000    0.000 array_exprs.py:34(match)
#         1    0.000    0.000    0.001    0.001 arraydecl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:162(GetItemBuffer)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:171(SetItemBuffer)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:236(ArrayAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:497(DTypeAttr)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:514(StaticGetItemArray)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:528(RecordAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:537(StaticGetItemRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:549(StaticSetItemRecord)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:562(ArrayCTypesAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:570(ArrayFlagsAttribute)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:584(NestedArrayAttribute)
#        11    0.000    0.000    0.000    0.000 arraydecl.py:715(install_array_method)
#         1    0.000    0.000    0.000    0.000 arraydecl.py:750(CmpOpEqArray)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1008(_partition_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1049(_select_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:1994(np_interp_impl_complex_fp_inner_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:2208(np_interp_impl_inner_factory)
#         1    0.000    0.000    0.062    0.062 arraymath.py:3(<module>)
#         1    0.000    0.000    0.050    0.050 arraymath.py:31(_check_blas)
#         2    0.000    0.000    0.000    0.000 arraymath.py:3364(_searchsorted)
#         2    0.000    0.000    0.000    0.000 arraymath.py:3680(generate_xinfo)
#         1    0.000    0.000    0.000    0.000 arraymath.py:3736(_corr_conv_Mode)
#         4    0.000    0.000    0.000    0.000 arraymath.py:4018(window_generator)
#         4    0.000    0.000    0.000    0.000 arraymath.py:692(nan_min_max_factory)
#         2    0.000    0.000    0.000    0.000 arraymath.py:916(_compute_current_val_impl_gen)
#         1    0.000    0.000    0.000    0.000 ast_transforms.py:10(<module>)
#         1    0.000    0.000    0.001    0.001 base.py:1(<module>)
#        58    0.000    0.000    0.000    0.000 base.py:105(<lambda>)
#        11    0.000    0.000    0.003    0.000 base.py:1078(get_abi_sizeof)
#       952    0.001    0.000    0.013    0.000 base.py:108(_match_arglist)
#        34    0.000    0.000    0.000    0.000 base.py:1108(active_code_library)
#         4    0.000    0.000    0.000    0.000 base.py:1114(push_code_library)
#        31    0.000    0.000    0.000    0.000 base.py:1124(add_linking_libs)
#        31    0.000    0.000    0.002    0.000 base.py:1139(__init__)
#     31/12    0.000    0.000    0.170    0.014 base.py:1145(__call__)
#        31    0.000    0.000    0.000    0.000 base.py:1150(__getattr__)
#        31    0.000    0.000    0.002    0.000 base.py:1156(_has_loc)
#        31    0.000    0.000    0.000    0.000 base.py:1165(__init__)
#        31    0.000    0.000    0.002    0.000 base.py:1168(__call__)
#     31/12    0.000    0.000    0.170    0.014 base.py:1174(wrapper)
#      1104    0.002    0.000    0.009    0.000 base.py:128(_match)
#      1252    0.001    0.000    0.061    0.000 base.py:143(append)
#         1    0.000    0.000    0.000    0.000 base.py:16(SparseWarning)
#         1    0.000    0.000    0.000    0.000 base.py:20(SparseFormatWarning)
#         1    0.000    0.000    0.000    0.000 base.py:24(SparseEfficiencyWarning)
#         2    0.000    0.000    0.153    0.076 base.py:267(refresh)
#         4    0.000    0.000    0.000    0.000 base.py:291(mangler)
#         4    0.000    0.000    0.000    0.000 base.py:297(get_env_name)
#         3    0.000    0.000    0.000    0.000 base.py:305(declare_env_global)
#        14    0.000    0.000    0.000    0.000 base.py:326(get_arg_packer)
#         1    0.000    0.000    0.003    0.003 base.py:336(nrt)
#         4    0.000    0.000    0.000    0.000 base.py:341(subtarget)
#        16    0.000    0.000    0.063    0.004 base.py:352(install_registry)
#        16    0.001    0.000    0.063    0.004 base.py:368(insert_func_defn)
#        16    0.000    0.000    0.000    0.000 base.py:372(_insert_getattr_defn)
#        16    0.000    0.000    0.000    0.000 base.py:376(_insert_setattr_defn)
#        16    0.000    0.000    0.000    0.000 base.py:380(_insert_cast_defn)
#        16    0.000    0.000    0.000    0.000 base.py:384(_insert_get_constant_defn)
#         1    0.000    0.000    0.000    0.000 base.py:388(insert_user_function)
#         4    0.000    0.000    0.001    0.000 base.py:419(declare_function)
#       546    0.001    0.000    0.001    0.000 base.py:42(__init__)
#         3    0.000    0.000    0.000    0.000 base.py:435(insert_const_string)
#        13    0.000    0.000    0.000    0.000 base.py:455(insert_unique_const)
#         8    0.000    0.000    0.000    0.000 base.py:467(get_argument_type)
#       113    0.000    0.000    0.015    0.000 base.py:47(find)
#       150    0.000    0.000    0.001    0.000 base.py:483(get_value_type)
#        54    0.000    0.000    0.007    0.000 base.py:504(get_constant_generic)
#         6    0.000    0.000    0.000    0.000 base.py:514(get_constant)
#     33/31    0.000    0.000    0.006    0.000 base.py:530(get_function)
#        53    0.000    0.000    0.014    0.000 base.py:54(_find)
#         3    0.000    0.000    0.000    0.000 base.py:581(get_getattr)
#        53    0.001    0.000    0.013    0.000 base.py:61(_select_compatible)
#         1    0.000    0.000    0.000    0.000 base.py:62(spmatrix)
#         3    0.000    0.000    0.000    0.000 base.py:655(get_returned_value)
#         6    0.000    0.000    0.000    0.000 base.py:661(get_return_value)
#         1    0.000    0.000    0.000    0.000 base.py:678(pair_first)
#         1    0.000    0.000    0.000    0.000 base.py:685(pair_second)
#   142/126    0.000    0.000    0.007    0.000 base.py:692(cast)
#        51    0.000    0.000    0.001    0.000 base.py:71(_best_signature)
#         1    0.000    0.000    0.000    0.000 base.py:737(is_true)
#         4    0.000    0.000    0.000    0.000 base.py:746(get_c_value)
#        14    0.000    0.000    0.000    0.000 base.py:79(<lambda>)
#         1    0.000    0.000    0.000    0.000 base.py:796(get_struct_type)
#         1    0.000    0.000    0.000    0.000 base.py:800(<listcomp>)
#        14    0.000    0.000    0.000    0.000 base.py:803(get_dummy_value)
#        14    0.000    0.000    0.000    0.000 base.py:806(get_dummy_type)
#         1    0.000    0.000    0.160    0.160 base.py:809(_compile_subroutine_no_cache)
#         2    0.000    0.000    0.160    0.080 base.py:838(compile_subroutine)
#         8    0.000    0.000    0.000    0.000 base.py:854(<genexpr>)
#         2    0.000    0.000    0.162    0.081 base.py:867(compile_internal)
#         2    0.000    0.000    0.002    0.001 base.py:875(call_internal)
#        51    0.000    0.000    0.001    0.000 base.py:88(_sort_signatures)
#         6    0.000    0.000    0.000    0.000 base.py:939(get_python_api)
#         3    0.000    0.000    0.000    0.000 base.py:955(get_helper_class)
#         3    0.000    0.000    0.001    0.000 base.py:963(_make_helper)
#         3    0.000    0.000    0.001    0.000 base.py:967(make_helper)
#         1    0.000    0.000    0.001    0.001 basic.py:3(<module>)
#         1    0.000    0.000    0.002    0.002 basic.py:7(<module>)
#         1    0.000    0.000    0.002    0.002 blas.py:202(<module>)
#         1    0.000    0.000    0.000    0.000 blas.py:233(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 blas.py:234(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 blas.py:365(_memoize_get_funcs)
#         1    0.000    0.000    0.001    0.001 boxing.py:46(unbox_integer)
#         1    0.000    0.000    0.000    0.000 boxing.py:62(box_float)
#         1    0.000    0.000    0.000    0.000 bsr.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 bsr.py:24(bsr_matrix)
#         1    0.000    0.000    0.000    0.000 bufproto.py:3(<module>)
#        18    0.000    0.000    0.000    0.000 builder.py:140(wrapped)
#        47    0.000    0.000    0.000    0.000 builder.py:153(_label_suffix)
#         3    0.000    0.000    0.000    0.000 builder.py:170(__init__)
#      1706    0.000    0.000    0.000    0.000 builder.py:175(block)
#       188    0.000    0.000    0.000    0.000 builder.py:184(function)
#         7    0.000    0.000    0.000    0.000 builder.py:191(module)
#         3    0.000    0.000    0.000    0.000 builder.py:198(position_before)
#        81    0.000    0.000    0.001    0.000 builder.py:20(wrapped)
#       297    0.000    0.000    0.000    0.000 builder.py:221(position_at_end)
#        49    0.000    0.000    0.000    0.000 builder.py:228(append_basic_block)
#       218    0.000    0.000    0.000    0.000 builder.py:235(goto_block)
#       214    0.000    0.000    0.002    0.000 builder.py:252(goto_entry_block)
#        48    0.000    0.000    0.000    0.000 builder.py:261(_branch_helper)
#        44    0.000    0.000    0.003    0.000 builder.py:268(if_then)
#         2    0.000    0.000    0.000    0.000 builder.py:291(if_else)
#      1177    0.001    0.000    0.001    0.000 builder.py:322(_insert)
#        85    0.000    0.000    0.000    0.000 builder.py:328(_set_terminator)
#         5    0.000    0.000    0.000    0.000 builder.py:510(not_)
#         2    0.000    0.000    0.000    0.000 builder.py:521(neg)
#        41    0.000    0.000    0.001    0.000 builder.py:532(_icmp)
#        22    0.000    0.000    0.000    0.000 builder.py:543(icmp_signed)
#        19    0.000    0.000    0.000    0.000 builder.py:552(icmp_unsigned)
#         4    0.000    0.000    0.000    0.000 builder.py:561(fcmp_ordered)
#         2    0.000    0.000    0.000    0.000 builder.py:576(fcmp_unordered)
#         5    0.000    0.000    0.000    0.000 builder.py:591(select)
#       108    0.000    0.000    0.002    0.000 builder.py:699(alloca)
#       361    0.001    0.000    0.005    0.000 builder.py:717(load)
#       372    0.001    0.000    0.006    0.000 builder.py:730(store)
#        30    0.000    0.000    0.001    0.000 builder.py:786(branch)
#        36    0.000    0.000    0.001    0.000 builder.py:794(cbranch)
#        19    0.000    0.000    0.000    0.000 builder.py:818(ret)
#        23    0.000    0.000    0.002    0.000 builder.py:835(call)
#        32    0.000    0.000    0.001    0.000 builder.py:876(gep)
#        46    0.000    0.000    0.001    0.000 builder.py:921(extract_value)
#         2    0.000    0.000    0.000    0.000 builtins.py:113(generic)
#         1    0.000    0.000    0.000    0.000 builtins.py:255(int_impl)
#         2    0.000    0.000    0.001    0.001 builtins.py:292(number_constructor)
#        10    0.000    0.000    0.000    0.000 builtins.py:312(constant_dummy)
#         1    0.000    0.000    0.000    0.000 builtins.py:404(bool_sequence)
#        18    0.000    0.000    0.000    0.000 builtins.py:458(generic)
#         4    0.000    0.000    0.000    0.000 builtins.py:757(resolve___call__)
#         4    0.000    0.000    0.000    0.000 builtins.py:763(typer)
#         1    0.000    0.000    0.000    0.000 builtins.py:875(generic)
#         9    0.000    0.000    0.000    0.000 builtins.py:88(none_equality)
#         2    0.000    0.000    0.000    0.000 builtins.py:903(generic)
#         2    0.000    0.000    0.000    0.000 builtins.py:93(generic)
#       136    0.000    0.000    0.000    0.000 bytecode.py:128(_unpack_opargs)
#       138    0.000    0.000    0.000    0.000 bytecode.py:159(_patched_opargs)
#         2    0.000    0.000    0.000    0.000 bytecode.py:175(__init__)
#         2    0.000    0.000    0.000    0.000 bytecode.py:179(__iter__)
#       138    0.000    0.000    0.000    0.000 bytecode.py:182(_fetch_opcode)
#       138    0.000    0.000    0.000    0.000 bytecode.py:185(next)
#         2    0.000    0.000    0.001    0.000 bytecode.py:207(__init__)
#        16    0.000    0.000    0.000    0.000 bytecode.py:210(<genexpr>)
#         2    0.000    0.000    0.000    0.000 bytecode.py:226(_compute_lineno)
#         2    0.000    0.000    0.000    0.000 bytecode.py:245(__iter__)
#       299    0.000    0.000    0.000    0.000 bytecode.py:248(__getitem__)
#         2    0.000    0.000    0.000    0.000 bytecode.py:25(get_function_object)
#         2    0.000    0.000    0.000    0.000 bytecode.py:312(from_function)
#         7    0.000    0.000    0.000    0.000 bytecode.py:37(get_code_object)
#       136    0.000    0.000    0.000    0.000 bytecode.py:74(__init__)
#       142    0.000    0.000    0.000    0.000 bytecode.py:82(is_jump)
#        34    0.000    0.000    0.000    0.000 bytecode.py:90(get_jump_target)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1011(UnaryOp)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1029(Union)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1048(While)
#         1    0.000    0.000    0.000    0.000 c_ast.py:1069(Pragma)
#         1    0.000    0.000    0.000    0.000 c_ast.py:109(NodeVisitor)
#         1    0.000    0.000    0.000    0.000 c_ast.py:167(ArrayDecl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:189(ArrayRef)
#         1    0.000    0.000    0.002    0.002 c_ast.py:19(<module>)
#         1    0.000    0.000    0.000    0.000 c_ast.py:210(Assignment)
#         1    0.000    0.000    0.000    0.000 c_ast.py:232(BinaryOp)
#         1    0.000    0.000    0.000    0.000 c_ast.py:254(Break)
#         1    0.000    0.000    0.000    0.000 c_ast.py:268(Case)
#         1    0.000    0.000    0.000    0.000 c_ast.py:290(Cast)
#         1    0.000    0.000    0.000    0.000 c_ast.py:30(Node)
#         1    0.000    0.000    0.000    0.000 c_ast.py:311(Compound)
#         1    0.000    0.000    0.000    0.000 c_ast.py:329(CompoundLiteral)
#         1    0.000    0.000    0.000    0.000 c_ast.py:350(Constant)
#         1    0.000    0.000    0.000    0.000 c_ast.py:367(Continue)
#         1    0.000    0.000    0.000    0.000 c_ast.py:381(Decl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:410(DeclList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:428(Default)
#         1    0.000    0.000    0.000    0.000 c_ast.py:446(DoWhile)
#         1    0.000    0.000    0.000    0.000 c_ast.py:467(EllipsisParam)
#         1    0.000    0.000    0.000    0.000 c_ast.py:481(EmptyStatement)
#         1    0.000    0.000    0.000    0.000 c_ast.py:495(Enum)
#         1    0.000    0.000    0.000    0.000 c_ast.py:513(Enumerator)
#         1    0.000    0.000    0.000    0.000 c_ast.py:531(EnumeratorList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:549(ExprList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:567(FileAST)
#         1    0.000    0.000    0.000    0.000 c_ast.py:585(For)
#         1    0.000    0.000    0.000    0.000 c_ast.py:614(FuncCall)
#         1    0.000    0.000    0.000    0.000 c_ast.py:635(FuncDecl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:656(FuncDef)
#         1    0.000    0.000    0.000    0.000 c_ast.py:682(Goto)
#         1    0.000    0.000    0.000    0.000 c_ast.py:698(ID)
#         1    0.000    0.000    0.000    0.000 c_ast.py:714(IdentifierType)
#         1    0.000    0.000    0.000    0.000 c_ast.py:730(If)
#         1    0.000    0.000    0.000    0.000 c_ast.py:755(InitList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:773(Label)
#         1    0.000    0.000    0.000    0.000 c_ast.py:791(NamedInitializer)
#         1    0.000    0.000    0.000    0.000 c_ast.py:813(ParamList)
#         1    0.000    0.000    0.000    0.000 c_ast.py:831(PtrDecl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:849(Return)
#         1    0.000    0.000    0.000    0.000 c_ast.py:866(Struct)
#         1    0.000    0.000    0.000    0.000 c_ast.py:885(StructRef)
#         1    0.000    0.000    0.000    0.000 c_ast.py:907(Switch)
#         1    0.000    0.000    0.000    0.000 c_ast.py:928(TernaryOp)
#         1    0.000    0.000    0.000    0.000 c_ast.py:953(TypeDecl)
#         1    0.000    0.000    0.000    0.000 c_ast.py:972(Typedef)
#         1    0.000    0.000    0.000    0.000 c_ast.py:992(Typename)
#         1    0.000    0.000    0.000    0.000 c_lexer.py:16(CLexer)
#         1    0.000    0.000    0.006    0.006 c_lexer.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 c_parser.py:19(CParser)
#         1    0.000    0.000    0.019    0.019 c_parser.py:9(<module>)
#         1    0.000    0.000    0.000    0.000 caching.py:100(save_overload)
#         1    0.000    0.000    0.000    0.000 caching.py:97(load_overload)
#         2    0.000    0.000    0.000    0.000 callconv.py:104(init_call_helper)
#         1    0.000    0.000    0.002    0.002 callconv.py:115(raise_error)
#         2    0.000    0.000    0.000    0.000 callconv.py:145(decode_arguments)
#        14    0.000    0.000    0.000    0.000 callconv.py:154(_get_arg_packer)
#         2    0.000    0.000    0.000    0.000 callconv.py:341(_make_call_helper)
#         6    0.000    0.000    0.000    0.000 callconv.py:344(return_value)
#         5    0.000    0.000    0.002    0.000 callconv.py:351(set_static_user_exc)
#         5    0.000    0.000    0.002    0.000 callconv.py:383(return_user_exc)
#         7    0.000    0.000    0.000    0.000 callconv.py:397(_get_try_state)
#         7    0.000    0.000    0.001    0.000 callconv.py:407(check_try_status)
#         2    0.000    0.000    0.000    0.000 callconv.py:438(return_status_propagate)
#        13    0.000    0.000    0.000    0.000 callconv.py:445(_return_errcode_raw)
#         3    0.000    0.000    0.000    0.000 callconv.py:448(_get_return_status)
#         5    0.000    0.000    0.000    0.000 callconv.py:472(get_function_type)
#         4    0.000    0.000    0.000    0.000 callconv.py:484(decorate_function)
#         4    0.000    0.000    0.000    0.000 callconv.py:490(<listcomp>)
#         6    0.000    0.000    0.000    0.000 callconv.py:508(get_arguments)
#        13    0.000    0.000    0.000    0.000 callconv.py:514(_get_return_argument)
#        18    0.000    0.000    0.000    0.000 callconv.py:517(_get_excinfo_argument)
#         3    0.000    0.000    0.001    0.000 callconv.py:520(call_function)
#         2    0.001    0.000    0.001    0.000 callconv.py:548(__init__)
#         2    0.000    0.000    0.001    0.000 callconv.py:551(fp_zero_division)
#         2    0.000    0.000    0.001    0.000 callconv.py:588(create_error_model)
#         5    0.000    0.000    0.000    0.000 callconv.py:97(get_return_type)
#         1    0.000    0.000    0.006    0.006 callwrapper.py:103(build)
#         1    0.000    0.000    0.006    0.006 callwrapper.py:128(build_wrapper)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:13(__init__)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:131(<listcomp>)
#         1    0.000    0.000    0.001    0.001 callwrapper.py:185(get_env)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:199(_simplified_return_type)
#         2    0.000    0.000    0.000    0.000 callwrapper.py:211(debug_print)
#         1    0.000    0.000    0.002    0.002 callwrapper.py:22(add_arg)
#         2    0.000    0.000    0.000    0.000 callwrapper.py:40(cleanup_arg)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:68(emit_cleanup)
#         1    0.000    0.000    0.000    0.000 callwrapper.py:94(__init__)
#         1    0.000    0.000    0.000    0.000 cffi_utils.py:185(FFI_from_buffer)
#         1    0.000    0.000    0.000    0.000 cffi_utils.py:205(FFIAttribute)
#        75    0.000    0.000    0.000    0.000 cffi_utils.py:30(is_ffi_instance)
#        75    0.000    0.000    0.001    0.000 cffi_utils.py:40(is_cffi_func)
#         1    0.000    0.000    0.047    0.047 cffi_utils.py:5(<module>)
#         1    0.000    0.000    0.000    0.000 cffiimpl.py:3(<module>)
#        10    0.000    0.000    0.000    0.000 cgutils.py:1102(normalize_ir_text)
#         7    0.000    0.000    0.001    0.000 cgutils.py:125(_make_refs)
#        20    0.000    0.000    0.001    0.000 cgutils.py:143(_get_ptr_by_index)
#        11    0.000    0.000    0.001    0.000 cgutils.py:150(__getattr__)
#        51    0.000    0.000    0.001    0.000 cgutils.py:159(__setattr__)
#        11    0.000    0.000    0.001    0.000 cgutils.py:167(__getitem__)
#         9    0.000    0.000    0.001    0.000 cgutils.py:174(__setitem__)
#         3    0.000    0.000    0.000    0.000 cgutils.py:209(_getvalue)
#         7    0.000    0.000    0.000    0.000 cgutils.py:229(_get_be_type)
#        11    0.000    0.000    0.000    0.000 cgutils.py:232(_cast_member_to_value)
#         9    0.000    0.000    0.000    0.000 cgutils.py:235(_cast_member_from_value)
#         1    0.000    0.000    0.000    0.000 cgutils.py:262(__init__)
#         7    0.000    0.000    0.000    0.000 cgutils.py:309(__setattr__)
#       107    0.001    0.000    0.008    0.000 cgutils.py:363(alloca_once)
#        10    0.000    0.000    0.000    0.000 cgutils.py:412(get_null_value)
#         1    0.000    0.000    0.000    0.000 cgutils.py:416(is_null)
#         3    0.000    0.000    0.000    0.000 cgutils.py:421(is_not_null)
#        10    0.000    0.000    0.000    0.000 cgutils.py:426(if_unlikely)
#         2    0.000    0.000    0.000    0.000 cgutils.py:430(if_likely)
#         8    0.000    0.000    0.000    0.000 cgutils.py:44(make_bytearray)
#         3    0.000    0.000    0.000    0.000 cgutils.py:56(create_struct_proxy)
#         2    0.000    0.000    0.000    0.000 cgutils.py:760(_scalar_pred_against_zero)
#         2    0.000    0.000    0.000    0.000 cgutils.py:771(is_scalar_zero)
#         4    0.000    0.000    0.000    0.000 cgutils.py:830(if_zero)
#         8    0.000    0.000    0.000    0.000 cgutils.py:842(is_pointer)
#        32    0.000    0.000    0.001    0.000 cgutils.py:859(gep_inbounds)
#        32    0.000    0.000    0.001    0.000 cgutils.py:866(gep)
#         1    0.000    0.000    0.000    0.000 cgutils.py:885(pointer_add)
#        13    0.000    0.000    0.000    0.000 cgutils.py:911(global_constant)
#         7    0.000    0.000    0.001    0.000 cgutils.py:99(__init__)
#         1    0.000    0.000    0.001    0.001 cmathdecl.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:13(CMath_unary)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:29(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:32(CMath_predicate)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:35(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:40(CMath_isfinite)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:45(Cmath_log)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:48(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:50(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:53(Cmath_phase)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:55(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:59(Cmath_polar)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:69(Cmath_rect)
#         1    0.000    0.000    0.000    0.000 cmathdecl.py:71(<listcomp>)
#         1    0.000    0.000    0.001    0.001 cmathimpl.py:3(<module>)
#         4    0.000    0.000    0.000    0.000 cmathimpl.py:95(intrinsic_complex_unary)
#         1    0.000    0.000    0.000    0.000 codecs.py:259(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:308(__init__)
#         8    0.000    0.000    0.000    0.000 codecs.py:318(decode)
#         1    0.000    0.000    0.000    0.000 codegen.py:103(codegen)
#         7    0.000    0.000    0.000    0.000 codegen.py:113(_raise_if_finalized)
#      10/7    0.000    0.000    0.041    0.006 codegen.py:118(_ensure_finalized)
#         3    0.000    0.000    0.009    0.003 codegen.py:122(_optimize_functions)
#         2    0.000    0.000    0.020    0.010 codegen.py:136(_optimize_final_module)
#         3    0.000    0.000    0.001    0.000 codegen.py:143(_get_module_for_linking)
#         2    0.000    0.000    0.000    0.000 codegen.py:178(create_ir_module)
#         5    0.000    0.000    0.010    0.002 codegen.py:186(add_linking_library)
#         3    0.000    0.000    0.032    0.011 codegen.py:194(add_ir_module)
#         3    0.000    0.000    0.010    0.003 codegen.py:206(add_llvm_module)
#         2    0.000    0.000    0.041    0.021 codegen.py:212(finalize)
#         2    0.000    0.000    0.000    0.000 codegen.py:244(_finalize_dyanmic_globals)
#         2    0.000    0.000    0.000    0.000 codegen.py:250(_verify_declare_only_symbols)
#         2    0.000    0.000    0.019    0.009 codegen.py:258(_finalize_final_module)
#         1    0.000    0.000    0.000    0.000 codegen.py:333(enable_object_caching)
#         2    0.000    0.000    0.000    0.000 codegen.py:380(_object_compiled_hook)
#         2    0.000    0.000    0.000    0.000 codegen.py:393(_object_getbuffer_hook)
#         2    0.000    0.000    0.031    0.016 codegen.py:475(get_pointer_to_function)
#         2    0.000    0.000    0.017    0.009 codegen.py:496(_finalize_specific)
#         2    0.000    0.000    0.000    0.000 codegen.py:512(scan_unresolved_symbols)
#         2    0.000    0.000    0.000    0.000 codegen.py:531(scan_defined_symbols)
#         2    0.000    0.000    0.000    0.000 codegen.py:539(resolve)
#         2    0.000    0.000    0.000    0.000 codegen.py:544(<listcomp>)
#         5    0.000    0.000    0.017    0.003 codegen.py:558(wrapper)
#         2    0.000    0.000    0.000    0.000 codegen.py:582(is_symbol_defined)
#         2    0.000    0.000    0.001    0.000 codegen.py:587(_load_defined_symbols)
#         4    0.000    0.000    0.000    0.000 codegen.py:591(<setcomp>)
#         2    0.000    0.000    0.001    0.000 codegen.py:594(add_module)
#         5    0.000    0.000    0.000    0.000 codegen.py:652(_create_empty_module)
#        11    0.000    0.000    0.000    0.000 codegen.py:659(target_data)
#         2    0.000    0.000    0.000    0.000 codegen.py:666(create_library)
#         3    0.000    0.000    0.004    0.001 codegen.py:683(_function_pass_manager)
#         3    0.000    0.000    0.000    0.000 codegen.py:690(_pass_manager_builder)
#         2    0.000    0.000    0.000    0.000 codegen.py:703(_check_llvm_bugs)
#         2    0.000    0.000    0.000    0.000 codegen.py:740(_scan_and_fix_unresolved_refs)
#         2    0.000    0.000    0.001    0.000 codegen.py:831(_add_module)
#         1    0.000    0.000    0.000    0.000 codegen.py:839(set_env)
#         2    0.000    0.000    0.000    0.000 codegen.py:87(__init__)
#         1    0.000    0.000    0.000    0.000 collections.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 collections.py:11(InContainer)
#         1    0.000    0.000    0.000    0.000 collections.py:20(ContainerLen)
#         1    0.000    0.000    0.000    0.000 collections.py:30(SequenceBool)
#         1    0.000    0.000    0.000    0.000 collections.py:41(GetItemSequence)
# ...
#        85    0.000    0.000    0.000    0.000 values.py:811(_format_name)
#         1    0.000    0.000    0.000    0.000 version.py:3(<module>)
#         1    0.000    0.000    0.001    0.001 warnings.py:119(filterwarnings)
#       124    0.000    0.000    0.001    0.000 warnings.py:143(simplefilter)
#       125    0.000    0.000    0.000    0.000 warnings.py:159(_add_filter)
#       124    0.000    0.000    0.000    0.000 warnings.py:428(__init__)
#       124    0.000    0.000    0.000    0.000 warnings.py:449(__enter__)
#       124    0.000    0.000    0.000    0.000 warnings.py:468(__exit__)
#         7    0.000    0.000    0.000    0.000 weakref.py:134(__getitem__)
#         7    0.000    0.000    0.000    0.000 weakref.py:165(__setitem__)
#         5    0.000    0.000    0.000    0.000 weakref.py:193(get)
#         7    0.000    0.000    0.000    0.000 weakref.py:334(__new__)
#         7    0.000    0.000    0.000    0.000 weakref.py:339(__init__)
#         1    0.000    0.000    0.000    0.000 weakref.py:354(__init__)
#       735    0.001    0.000    0.003    0.000 weakref.py:393(__getitem__)
#        30    0.000    0.000    0.000    0.000 weakref.py:406(__setitem__)
#         5    0.000    0.000    0.000    0.000 weakref.py:526(__init__)
#         1    0.000    0.000    0.000    0.000 yacc.py:109(PlyLogger)
#         1    0.000    0.000    0.000    0.000 yacc.py:127(NullLogger)
#         1    0.000    0.000    0.000    0.000 yacc.py:1309(Production)
#         1    0.000    0.000    0.000    0.000 yacc.py:135(YaccError)
#         1    0.000    0.000    0.000    0.000 yacc.py:1381(MiniProduction)
#         1    0.000    0.000    0.000    0.000 yacc.py:1427(LRItem)
#         1    0.000    0.000    0.000    0.000 yacc.py:1470(GrammarError)
#         1    0.000    0.000    0.000    0.000 yacc.py:1473(Grammar)
#         1    0.000    0.000    0.000    0.000 yacc.py:1968(VersionError)
#         1    0.000    0.000    0.000    0.000 yacc.py:1971(LRTable)
#         1    0.000    0.000    0.000    0.000 yacc.py:2089(LALRError)
#         1    0.000    0.000    0.000    0.000 yacc.py:2099(LRGeneratedTable)
#         1    0.000    0.000    0.000    0.000 yacc.py:217(YaccSymbol)
#         1    0.000    0.000    0.000    0.000 yacc.py:233(YaccProduction)
#         1    0.000    0.000    0.000    0.000 yacc.py:285(LRParser)
#         1    0.000    0.000    0.000    0.000 yacc.py:2936(ParserReflect)
#         1    0.000    0.000    0.002    0.002 yacc.py:62(<module>)
#       359    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x9d12c0}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend._get_common_types}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend._get_types}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.cast}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.new_array_type}
#         2    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.new_pointer_type}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.new_primitive_type}
#         1    0.000    0.000    0.000    0.000 {built-in method _cffi_backend.new_void_type}
#         8    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#        36    0.000    0.000    0.000    0.000 {built-in method _ctypes.byref}
#        12    0.000    0.000    0.000    0.000 {built-in method _ctypes.sizeof}
#      3348    0.002    0.000    0.002    0.000 {built-in method _functools.reduce}
#       113    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#      1164    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.create_builtin}
#        20    0.021    0.001    0.021    0.001 {built-in method _imp.create_dynamic}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.exec_builtin}
#     20/17    0.003    0.000    0.005    0.000 {built-in method _imp.exec_dynamic}
#         5    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#       137    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#      1164    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         5    0.000    0.000    0.000    0.000 {built-in method _pickle.dumps}
#        23    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#        67    0.000    0.000    0.000    0.000 {built-in method _sre.getlower}
#         9    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#         9    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#       278    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       368    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       373    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         4    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#       553    0.011    0.000    0.012    0.000 {built-in method builtins.__build_class__}
#     56/27    0.000    0.000    0.149    0.006 {built-in method builtins.__import__}
#       458    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#      1088    0.001    0.000    0.003    0.000 {built-in method builtins.any}
#        31    0.000    0.000    0.000    0.000 {built-in method builtins.bin}
#      1097    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.eval}
#     121/1    0.003    0.000    0.676    0.676 {built-in method builtins.exec}
# 10093/10062    0.004    0.000    0.004    0.000 {built-in method builtins.getattr}
#       628    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#      4698    0.003    0.000    0.003    0.000 {built-in method builtins.hasattr}
# 2670/2406    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#       640    0.000    0.000    0.000    0.000 {built-in method builtins.id}
# 94397/94396    0.075    0.000    0.091    0.000 {built-in method builtins.isinstance}
# 2136/1575    0.001    0.000    0.008    0.000 {built-in method builtins.issubclass}
#       397    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 14478/14417    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#       403    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       409    0.000    0.000    0.000    0.000 {built-in method builtins.min}
# 2685/2421    0.001    0.000    0.009    0.000 {built-in method builtins.next}
#       276    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#       157    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#      2677    0.001    0.000    0.001    0.000 {built-in method builtins.setattr}
# 1768/1713    0.002    0.000    0.002    0.000 {built-in method builtins.sorted}
#       226    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#       113    0.014    0.000    0.014    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.000    0.000 {built-in method numba._dynfunc.make_function}
#      1289    0.000    0.000    0.000    0.000 {built-in method numba.typeconv._typeconv.check_compatible}
#         5    0.000    0.000    0.000    0.000 {built-in method numba.typeconv._typeconv.get_pointer}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#      1088    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.promote_types}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.cpu_count}
#       476    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        18    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#        10    0.000    0.000    0.000    0.000 {built-in method posix.listdir}
#       441    0.004    0.000    0.004    0.000 {built-in method posix.stat}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy._lib._uarray._uarray.set_global_backend}
#        25    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#        77    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#       240    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#       498    0.000    0.000    0.000    0.000 {function TargetRegistry.__getitem__ at 0x7f0a3a6b6ae8}
#        61    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         6    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#       870    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#       901    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#         1    0.000    0.000    0.000    0.000 {method '_insert' of '_dispatcher.Dispatcher' objects}
#         2    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#        44    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#      9560    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#     15834    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        18    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#      1254    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       156    0.000    0.000    0.000    0.000 {method 'clear' of 'frame' objects}
#       231    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       194    0.000    0.000    0.000    0.000 {method 'copy' of 'set' objects}
#       255    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       616    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       161    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        22    0.000    0.000    0.000    0.000 {method 'end' of '_sre.SRE_Match' objects}
#       295    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'expandtabs' of 'str' objects}
#     12465    0.002    0.000    0.002    0.000 {method 'extend' of 'list' objects}
#        90    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
# 6853/3676    0.005    0.000    0.019    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#      4489    0.001    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        24    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#         2    0.000    0.000    0.000    0.000 {method 'groups' of '_sre.SRE_Match' objects}
#         3    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#       108    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#      1605    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        92    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#       378    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#      2025    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        75    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
# 2988/2981    0.001    0.000    0.002    0.000 {method 'join' of 'str' objects}
#       249    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        41    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       124    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#       111    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'mro' of 'type' objects}
#         2    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.generic' objects}
#         4    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#      2025    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#      3453    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#       113    0.026    0.000    0.026    0.000 {method 'read' of '_io.FileIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.001    0.001    0.001    0.001 {method 'readlines' of '_io._IOBase' objects}
#        44    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       126    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       903    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       345    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        64    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        23    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      1982    0.001    0.000    0.001    0.000 {method 'rpartition' of 'str' objects}
#      3045    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         6    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        76    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        75    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#      2214    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#        35    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        22    0.000    0.000    0.000    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'tobytes' of 'numpy.generic' objects}
#         4    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#       890    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#      1320    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#        27    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      4881    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#        29    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        78    0.000    0.000    0.000    0.000 {method 'with_traceback' of 'BaseException' objects}

# %% [markdown]
# When we run the two pieces of code, we notice two things. Firstly, the version with the Numba decortator compiles much faster (when I ran it, about 0.3s compared to about 6s). The second is that the list of called functions is much longer in the compiled version. This is because cProfile has recorded the process of compilation as well as the running of the code. Most of this complexity is simply the detail of the implementation and can be ignored.
#
# The important thing to notice is that Numba was able to speed up the execution of this code significantly with minimal changes to the source code required. This makes Numba a good choice to easily get some extra speed, by compiling heavily used functions in your code.
